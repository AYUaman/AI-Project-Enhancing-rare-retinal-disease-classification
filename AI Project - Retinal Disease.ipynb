# %% [markdown]
# ## DATA HANDLING

# %%
import os
import pandas as pd
import shutil

# Define paths to the dataset folders
base_path = r'C:\\Users\\mayan\\Documents\\RFMiD'
training_path = os.path.join(base_path, 'Training_Set\\Training')
evaluation_path = os.path.join(base_path, 'Evaluation_Set\\Validation')
testing_path = os.path.join(base_path, 'Test_Set\\Test')

# Define paths to the CSV label files
training_labels_path = os.path.join(base_path, 'Training_Set\\RFMiD_Training_Labels.csv')
evaluation_labels_path = os.path.join(base_path, 'Evaluation_Set\\RFMiD_Validation_Labels.csv')
testing_labels_path = os.path.join(base_path, 'Test_Set\\RFMiD_Testing_Labels.csv')

# Load CSV files into DataFrames
training_labels = pd.read_csv(training_labels_path)
evaluation_labels = pd.read_csv(evaluation_labels_path)
testing_labels = pd.read_csv(testing_labels_path)

# Create a directory for the combined dataset
combined_images_path = os.path.join(base_path, 'combined_dataset\\images')
os.makedirs(combined_images_path, exist_ok=True)

# Initialize a counter for new image naming
new_image_id = 1
new_labels = []

# Function to copy images with new sequential numbering
def copy_images(src_folder, labels_df):
    global new_image_id
    for _, row in labels_df.iterrows():
        old_image_name = f"{row['ID']}.png"  # Original numeric filename
        new_image_name = f"{new_image_id}.png"  # New consecutive filename
        
        src_image_path = os.path.join(src_folder, old_image_name)
        dest_image_path = os.path.join(combined_images_path, new_image_name)
        
        # Debug: Print paths to check correctness
        print(f"Copying from: {src_image_path} to {dest_image_path}")
        
        if os.path.exists(src_image_path):  # Copy only if the source image exists
            shutil.copy2(src_image_path, dest_image_path)
            # Update the row with the new image ID and add it to the new labels list
            row['ID'] = new_image_id
            new_labels.append(row)
            new_image_id += 1
        else:
            print(f"File not found: {src_image_path}")

# Copy images from each folder to the combined directory with new numbering
copy_images(training_path, training_labels)
copy_images(evaluation_path, evaluation_labels)
copy_images(testing_path, testing_labels)

# Create a DataFrame from the updated labels
combined_labels_df = pd.DataFrame(new_labels)

# Save the combined labels to a new CSV file
combined_labels_path = os.path.join(base_path, 'combined_dataset\\RFMiD_combined_labels.csv')
combined_labels_df.to_csv(combined_labels_path, index=False)

print("Dataset combined successfully!")
# Out:
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\1.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\1.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\2.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\2.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\3.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\3.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\4.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\4.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\5.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\5.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\6.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\6.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\7.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\7.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\8.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\8.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\9.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\9.png
# File not found: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\9.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\10.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\9.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\11.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\10.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\12.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\11.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\13.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\12.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\14.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\13.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\15.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\14.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\16.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\15.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\17.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\16.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\18.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\17.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\19.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\18.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\20.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\19.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\21.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\20.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\22.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\21.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\23.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\22.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\24.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\23.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\25.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\24.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\26.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\25.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\27.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\26.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\28.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\27.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\29.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\28.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\30.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\29.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\31.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\30.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\32.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\31.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\33.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\32.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\34.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\33.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\35.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\34.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\36.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\35.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\37.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\36.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\38.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\37.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\39.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\38.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\40.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\39.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\41.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\40.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\42.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\41.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\43.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\42.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\44.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\43.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\45.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\44.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\46.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\45.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\47.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\46.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\48.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\47.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\49.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\48.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\50.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\49.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\51.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\50.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\52.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\51.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\53.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\52.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\54.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\53.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\55.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\54.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\56.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\55.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\57.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\56.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\58.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\57.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\59.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\58.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\60.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\59.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\61.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\60.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\62.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\61.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\63.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\62.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\64.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\63.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\65.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\64.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\66.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\65.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\67.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images\66.png
# Copying from: C:\\Users\\mayan\\Documents\\RFMiD\Training_Set\Training\68.png to C:\\Users\\mayan\\Documents\\RFMiD\combined_dataset\images
disease_counts_df = pd.DataFrame(disease_counts, columns=['Number of Samples'])
disease_counts_df.index.name = 'Disease'
disease_counts_df.loc['Normal'] = normal_count
# Display the table
print(disease_counts_df)
# Out:
#          Number of Samples
# Disease
# DR                     611
# ARMD                   163
# MH                     489
# DN                     209
# MYA                    161
# BRVO                   112
# TSLN                   293
# ERM                     23
# LS                      75
# MS                      26
# CSR                     44
# ODC                    423
# CRVO                    40
# TV                       8
# AH                      25
# ODP                    106
# ODE                     84
# ST                      11
# AION                    18
# PT                      16
# RT                      25
# RS                      62
# CRS                     50
# EDN                     23
# RPEC                    29
# MHL                     16
# RP                      10
# CWS                      7
# CB                       1
# ODPM                     2
# PRH                      4
# MNF                      1
# HR                       1
# CRAO                     4
# TD                       9
# CME                      6
# PTCR                     4
# CF                       6
# VH                       4
# MCA                      1
# VS                       4
# BRAO                     3
# PLQ                      2
# HPED                     1
# CL                       2
# Normal                 620

# %%
# Identify diseases with less than 10 samples and calculate the total count for 'Other'
other_count = disease_counts_df[disease_counts_df['Number of Samples'] < 10]['Number of Samples'].sum()

# Filter out diseases with less than 10 samples
disease_counts_df = disease_counts_df[disease_counts_df['Number of Samples'] >= 10]

# Add the 'Other' row to the DataFrame
disease_counts_df.loc['Other'] = other_count

# Display the updated table
print(disease_counts_df)
# Out:
#          Number of Samples
# Disease
# DR                     611
# ARMD                   163
# MH                     489
# DN                     209
# MYA                    161
# BRVO                   112
# TSLN                   293
# ERM                     23
# LS                      75
# MS                      26
# CSR                     44
# ODC                    423
# CRVO                    40
# AH                      25
# ODP                    106
# ODE                     84
# ST                      11
# AION                    18
# PT                      16
# RT                      25
# RS                      62
# CRS                     50
# EDN                     23
# RPEC                    29
# MHL                     16
# RP                      10
# Normal                 620
# Other                   70

# %%
# Define the output path where disease-specific folders will be created
output_base_path = r'C:\Users\mayan\Documents\RFMiD\separated_diseases'
os.makedirs(output_base_path, exist_ok=True)

# List of diseases that should have their own folder
Diseases = [
    "DR", "ARMD", "MH", "DN", "MYA", "BRVO", "TSLN", "ERM", "LS", "MS", 
    "CSR", "ODC", "CRVO", "AH", "ODP", "ODE", "ST", "AION", "PT", 
    "RT", "RS", "CRS", "EDN", "RPEC", "MHL", "RP"
]

# Assuming combined_labels_df is your combined DataFrame
# The DataFrame `new` should be for the "Other" category, i.e., diseases not in `Diseases`

# Create folders for each disease and copy associated images
for disease in Diseases + ['Normal', 'Other']:
    # Filter images associated with the current disease
    if disease == 'Normal':
        # Filter rows where Disease Risk is 0 (Normal)
        disease_df = combined_labels_df[combined_labels_df['Disease_Risk'] == 0]
    elif disease == 'Other':
    # Filter rows where none of the diseases in Diseases list is marked as 1
    # AND Disease_Risk is 1
        disease_df = combined_labels_df[
            (~combined_labels_df[Diseases].any(axis=1)) & (combined_labels_df['Disease_Risk'] == 1)
        ]
    else:
        # For individual diseases, filter rows where the disease column is 1
        disease_df = combined_labels_df[combined_labels_df[disease] == 1]

    # Define the disease folder path
    disease_folder_path = os.path.join(output_base_path, disease)
    os.makedirs(disease_folder_path, exist_ok=True)
    
    # Copy images to the disease folder
    for _, row in disease_df.iterrows():
        image_name = f"{row['ID']}.png"  # Assuming images are in PNG format, or adjust if they are JPG
        src_image_path = os.path.join(combined_images_path, image_name)
        dest_image_path = os.path.join(disease_folder_path, image_name)
        
        if os.path.exists(src_image_path):
            shutil.copy2(src_image_path, dest_image_path)
    
    # Save disease-specific CSV
    disease_csv_path = os.path.join(disease_folder_path, f"{disease}_labels.csv")
    disease_df.to_csv(disease_csv_path, index=False)

print("Disease-specific folders and label files created successfully!")
# Out:
# Disease-specific folders and label files created successfully!

# %%
from PIL import Image

# Define paths
output_base_path = r'C:\Users\mayan\Documents\RFMiD\separated_diseases'  # Path to the disease folders
Diseases = [
    "DR", "ARMD", "MH", "DN", "MYA", "BRVO", "TSLN", "ERM", "LS", "MS", 
    "CSR", "ODC", "CRVO", "AH", "ODP", "ODE", "ST", "AION", "PT", 
    "RT", "RS", "CRS", "EDN", "RPEC", "MHL", "RP", "Normal", "Other"
]

# Desired number of images per class
target_count = 100

# Define augmentation function (horizontal and vertical flip)
def augment_image(image_path):
    image = Image.open(image_path)
    
    # Create horizontal flip
    horizontal_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
    
    # Create vertical flip
    vertical_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
    
    return [horizontal_flip, vertical_flip]

# Iterate over each disease folder
for disease in Diseases:
    disease_folder_path = os.path.join(output_base_path, disease)
    if not os.path.exists(disease_folder_path):
        continue  # Skip if folder does not exist
    
    # Get all image paths in the disease folder
    image_paths = [os.path.join(disease_folder_path, f) for f in os.listdir(disease_folder_path) if f.endswith('.png')]
    
    # Check the current number of images in the folder
    current_image_count = len(image_paths)
    
    # If there are fewer than target_count images, augment them
    if current_image_count < target_count:
        num_to_augment = target_count - current_image_count
        
        # Perform augmentation to generate more images
        augmented_images = []
        
        for image_path in image_paths:
            augmented_images.extend(augment_image(image_path))
        
        # If the number of augmented images is less than needed, repeat augmentation
        augmented_images = augmented_images * (num_to_augment // len(augmented_images)) + augmented_images[:(num_to_augment % len(augmented_images))]
        
        # Save augmented images to the disease folder
        for i, augmented_image in enumerate(augmented_images[:num_to_augment]):
            augmented_image_path = os.path.join(disease_folder_path, f"aug_{i + current_image_count}.png")
            augmented_image.save(augmented_image_path)
            
        print(f"Augmented {num_to_augment} images for disease '{disease}'.")

print("Data augmentation completed for all necessary classes.")
# Out:
# Augmented 77 images for disease 'ERM'.
# Augmented 25 images for disease 'LS'.
# Augmented 74 images for disease 'MS'.
# Augmented 56 images for disease 'CSR'.
# Augmented 60 images for disease 'CRVO'.
# Augmented 75 images for disease 'AH'.
# Augmented 16 images for disease 'ODE'.
# Augmented 89 images for disease 'ST'.
# Augmented 82 images for disease 'AION'.
# Augmented 84 images for disease 'PT'.
# Augmented 75 images for disease 'RT'.
# Augmented 38 images for disease 'RS'.
# Augmented 50 images for disease 'CRS'.
# Augmented 77 images for disease 'EDN'.
# Augmented 71 images for disease 'RPEC'.
# Augmented 84 images for disease 'MHL'.
# Augmented 90 images for disease 'RP'.
# Augmented 75 images for disease 'Other'.
# Data augmentation completed for all necessary classes.

# %%
MODEL

# %%
import os

# Path to the folder containing disease subfolders with images
separated_images_folder = r'C:\Users\mayan\Documents\RFMiD\separated_diseases'

# Initialize the dictionary to hold classes as keys and image paths as values
data = {}

# Iterate through each disease subfolder
for disease_folder in os.listdir(separated_images_folder):
    class_path = os.path.join(separated_images_folder, disease_folder)
    
    # Ensure it's a directory (skip files if any)
    if os.path.isdir(class_path):
        # List all images in the current disease folder
        image_paths = [os.path.join(class_path, img) for img in os.listdir(class_path) if img.endswith(('.png', '.jpg', '.jpeg'))]
        
        # Add the list of image paths to the data dictionary under the disease label
        data[disease_folder] = image_paths

# Now, 'data' contains classes as keys and lists of image paths as values
print(data)
# Out:
# {'AH': ['C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1172.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1225.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1227.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1228.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1264.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\130.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1332.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1568.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1932.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2091.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2105.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2253.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2371.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2434.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2788.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2794.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\281.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2884.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\342.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\583.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\584.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\690.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\796.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\916.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\92.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_25.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_26.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_27.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_28.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_29.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_30.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_31.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_32.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_33.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_34.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_35.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_36.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_37.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_38.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_39.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_40.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_41.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_42.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_43.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_44.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_45.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_46.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_47.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_48.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_49.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_50.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_51.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_52.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_53.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\ ...

# %%
import os
import random

# Assuming 'data' is structured as:
# data = {
#     "DR": ["path_to_image1.jpg", "path_to_image2.jpg", ...],
#     "ARMD": ["path_to_image3.jpg", "path_to_image4.jpg", ...],
#     ...
# }

# Load data from your image folder
def load_data(image_folder):
    data = {}
    for disease in os.listdir(image_folder):
        disease_folder = os.path.join(image_folder, disease)
        if os.path.isdir(disease_folder):
            data[disease] = [os.path.join(disease_folder, img) for img in os.listdir(disease_folder)]
    return data

# Load the RFMiD dataset
data = load_data(r'C:\Users\mayan\Documents\RFMiD\separated_diseases')

# Define few-shot classes and split into Df and Dm
few_shot_classes = ["MHL", "RP", "ST", "TV"]
Df = {cls: data[cls] for cls in few_shot_classes if cls in data}
Dm = {cls: data[cls] for cls in data.keys() if cls not in few_shot_classes}

# Split Dm into training and testing subsets
Dm_train = {}
Dm_test = {}

for cls, images in Dm.items():
    # Shuffle the images to ensure randomness
    random.shuffle(images)
    # Calculate the split index
    split_idx = int(len(images) * 0.75)
    # Split into train and test
    Dm_train[cls] = images[:split_idx]
    Dm_test[cls] = images[split_idx:]

# Generate triplets from Dm_train
def generate_triplets(Dm_train, num_triplets_per_class=10):
    triplets = []
    for cls, images in Dm_train.items():
        if len(images) < 2:
            continue  # Skip classes with fewer than 2 images
        for _ in range(num_triplets_per_class):
            anchor = random.choice(images)
            positive = random.choice([img for img in images if img != anchor])
            negative_class = random.choice([neg_cls for neg_cls in Dm_train.keys() if neg_cls != cls])
            negative = random.choice(Dm_train[negative_class])
            triplets.append((anchor, positive, negative))
    return triplets

# Generate triplets
triplets = generate_triplets(Dm_train)
print(triplets)
# triplets will contain tuples of the form (anchor, positive, negative)
# Out:
# [('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_80.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_36.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\CRVO\\aug_77.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_54.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_79.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\ODE\\387.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_56.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\583.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\PT\\aug_18.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1264.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_37.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\MS\\aug_63.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\342.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_95.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\TSLN\\345.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_51.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\1264.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\Other\\1383.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_93.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_52.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\CSR\\aug_92.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_43.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_63.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\CSR\\744.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\2794.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_42.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\Normal\\2791.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\916.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AH\\aug_44.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\ODP\\651.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\1726.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_29.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\ARMD\\1910.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_96.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_75.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\DR\\285_vertical.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_36.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_42.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\ARMD\\384.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_77.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_71.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\MYA\\2108.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_77.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_84.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\ODC\\1289.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_77.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_98.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\EDN\\aug_61.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_34.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\357.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\MS\\aug_81.png'), ('C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\aug_84.png', 'C:\\Users\\mayan\\Documents\\RFMiD\\separated_diseases\\AION\\1405.png', 'C:\\Users\\mayan\\Documents\ ...

# %%
import tensorflow as tf
import numpy as np
import os
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input

# Constants
batch_size = 32
img_size = (224, 224)

# Preprocess function
def preprocess_image(img_path, img_size, model_name='VGG16'):
    try:
        img = image.load_img(img_path, target_size=img_size)
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        if model_name == 'VGG16':
            img_array = preprocess_input(img_array)
        return img_array[0]
    except Exception as e:
        print(f"Error loading image {img_path}: {e}")
        return None

# Triplet Loss function
def triplet_loss(y_true, y_pred, margin=1.0):
    anchor, positive, negative = y_pred[0], y_pred[1], y_pred[2]
    pos_dist = tf.reduce_sum(tf.square(anchor - positive), axis=-1)
    neg_dist = tf.reduce_sum(tf.square(anchor - negative), axis=-1)
    basic_loss = pos_dist - neg_dist + margin
    loss = tf.reduce_mean(tf.maximum(basic_loss, 0.0))
    return loss

# Create the base model for embeddings
def create_base_model(input_shape):
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    model = models.Sequential([
        base_model,
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Lambda(lambda x: tf.math.l2_normalize(x, axis=1))
    ])
    return model

# Load base model and inputs
input_shape = (224, 224, 3)
base_model = create_base_model(input_shape)

# Input layers for anchor, positive, and negative images
input_anchor = layers.Input(shape=input_shape, name="anchor")
input_positive = layers.Input(shape=input_shape, name="positive")
input_negative = layers.Input(shape=input_shape, name="negative")

# Generate embeddings for each input
embedding_anchor = base_model(input_anchor)
embedding_positive = base_model(input_positive)
embedding_negative = base_model(input_negative)

# Concatenate embeddings for triplet loss
triplet_output = [embedding_anchor, embedding_positive, embedding_negative]
triplet_model = models.Model(inputs=[input_anchor, input_positive, input_negative], outputs=triplet_output)

# Compile model with triplet loss
triplet_model.compile(optimizer='adam', loss=triplet_loss)

# Define output signature for the dataset with explicit batch dimension
output_signature = (
    {
        "anchor": tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),
        "positive": tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),
        "negative": tf.TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32),
    },
    tf.TensorSpec(shape=(None,), dtype=tf.float32)  # Dummy labels
)

# Modify the generator to return the correct format with batch dimension
def triplets_data_generator(triplets, batch_size, img_size, model_name='VGG16'):
    while True:
        batch_anchor, batch_positive, batch_negative = [], [], []
        np.random.shuffle(triplets)
        for i in range(batch_size):
            triplet = triplets[i % len(triplets)]
            anchor_path, positive_path, negative_path = triplet
            anchor_img = preprocess_image(anchor_path, img_size, model_name)
            positive_img = preprocess_image(positive_path, img_size, model_name)
            negative_img = preprocess_image(negative_path, img_size, model_name)
            if anchor_img is None or positive_img is None or negative_img is None:
                continue
            batch_anchor.append(anchor_img)
            batch_positive.append(positive_img)
            batch_negative.append(negative_img)
        
        # Ensure batch outputs have batch dimension
        if len(batch_anchor) == batch_size:
            yield (
                {
                    "anchor": np.array(batch_anchor),
                    "positive": np.array(batch_positive),
                    "negative": np.array(batch_negative),
                },
                np.zeros((batch_size,))  # Dummy labels with batch dimension
            )



# Define steps per epoch
steps_per_epoch = int(np.ceil(len(triplets) / batch_size))

# Create dataset from generator with the updated output signature
dataset = tf.data.Dataset.from_generator(
    lambda: triplets_data_generator(triplets, batch_size=batch_size, img_size=img_size),
    output_signature=output_signature
)

# Train the model
triplet_model.fit(
    dataset,
    steps_per_epoch=steps_per_epoch,
    epochs=20
)
# Out:
# Epoch 1/20
# C:\Users\mayan\anaconda3\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['anchor', 'positive', 'negative']. Received: the structure of inputs={'anchor': '*', 'positive': '*', 'negative': '*'}
#   warnings.warn(
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 160s 19s/step - loss: 0.9033
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 151s 19s/step - loss: 1.0002
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 1.0002
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 134s 17s/step - loss: 1.0021
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 129s 16s/step - loss: 0.9962
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 1.0012
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 133s 17s/step - loss: 0.9999
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 133s 17s/step - loss: 1.0001
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 134s 17s/step - loss: 1.0001
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 134s 17s/step - loss: 0.9999
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 1.0003
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 129s 16s/step - loss: 1.0001
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.9999
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 131s 16s/step - loss: 0.9994
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 134s 17s/step - loss: 1.0001
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 135s 17s/step - loss: 0.9999
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 133s 17s/step - loss: 1.0005
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 132s 17s/step - loss: 1.0000
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 131s 16s/step - loss: 1.0000
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 131s 16s/step - loss: 1.0000

# %%
import numpy as np
import random

# Function to generate test triplets
def generate_test_triplets(Dm_test, num_triplets_per_class=10):
    triplets = []
    for cls, images in Dm_test.items():
        if len(images) < 2:
            continue  # Skip classes with fewer than 2 images
        for _ in range(num_triplets_per_class):
            anchor = random.choice(images)
            positive = random.choice([img for img in images if img != anchor])
            negative_class = random.choice([neg_cls for neg_cls in Dm_test.keys() if neg_cls != cls])
            negative = random.choice(Dm_test[negative_class])
            triplets.append((anchor, positive, negative))
    return triplets

# Generate test triplets
test_triplets = generate_test_triplets(Dm_test)

# Function to preprocess image and generate embeddings
def preprocess_image(img_path, img_size=(224, 224)):
    try:
        img = image.load_img(img_path, target_size=img_size)
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)
        return img_array[0]
    except Exception as e:
        print(f"Error loading image {img_path}: {e}")
        return None

# Function to generate embeddings for a list of image paths
def generate_embeddings(model, image_paths, img_size=(224, 224)):
    embeddings = []
    for img_path in image_paths:
        img_array = preprocess_image(img_path, img_size)
        if img_array is not None:
            embedding = model.predict(np.expand_dims(img_array, axis=0))
            embeddings.append(embedding[0])  # Store the embedding (flattened vector)
    return np.array(embeddings)

# Extract test labels and image paths from the test triplets
test_image_paths = [triplet[0] for triplet in test_triplets]  # Anchors in the test triplet
test_labels = [label for triplet in test_triplets for label in [triplet[0]] * 1]  # Labels for anchors

# Generate embeddings for test images (anchors)
test_embeddings = generate_embeddings(base_model, test_image_paths)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step

# %%
# Assuming you have your test_labels and test_embeddings, you can now train a KNN classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Initialize and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(test_embeddings, test_labels)

# Generate predictions on the test set
predictions = knn.predict(test_embeddings)

# Calculate accuracy
accuracy = accuracy_score(test_labels, predictions)
print(f"KNN Classifier Accuracy: {accuracy * 100:.2f}%")
# Out:
# KNN Classifier Accuracy: 30.80%
